# %%
str = input("Input your stage of your origin.")

print("Your state of origin is: ", str)
print("The first character is: ", str[0])
print("The characters starting from  3rd to 5th are: ", str[2::5])
print("The string starting from the third character is: ",str[2:])
print("The state of origin two times", str * 2)
# Out:
# Input your stage of your origin. Imowe
# Your state of origin is:  Imowe
# The first character is:  I
# The characters starting from  3rd to 5th are:  o
# The string starting from the third character is:  owe
# The state of origin two times ImoweImowe
